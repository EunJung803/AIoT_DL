# %% [markdown]
# # MNIST - Categorical Classification
# > # Model Capacity
# ## Import Tensorflow & Keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * TensorFlow Version 지정

# %%
# %tensorflow_version 1.x
import tensorflow as tf

tf.__version__
# Out:
# '2.5.0'

# %% [markdown]
# * GPU 설정 확인

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
train_images = train_images.reshape((60000, 28 * 28))
test_images = test_images.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
train_images = train_images.astype(float) / 255
test_images = test_images.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 1개의 Hidden Layer & 256개의 Nodes
#  - Model Capacity 낮게 조정

# %%
from keras import models
from keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(256, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 모델 학습 수행(약 2분)

# %%
Hist_mnist = mnist.fit(train_images, train_labels,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 15s 4ms/step - loss: 0.5172 - accuracy: 0.8559 - val_loss: 0.1669 - val_accuracy: 0.9532
# Epoch 2/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1537 - accuracy: 0.9557 - val_loss: 0.1179 - val_accuracy: 0.9648
# Epoch 3/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0986 - accuracy: 0.9703 - val_loss: 0.1096 - val_accuracy: 0.9695
# Epoch 4/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0710 - accuracy: 0.9791 - val_loss: 0.0875 - val_accuracy: 0.9749
# Epoch 5/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0536 - accuracy: 0.9845 - val_loss: 0.0853 - val_accuracy: 0.9753
# Epoch 6/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0417 - accuracy: 0.9887 - val_loss: 0.0850 - val_accuracy: 0.9748
# Epoch 7/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0358 - accuracy: 0.9907 - val_loss: 0.0794 - val_accuracy: 0.9775
# Epoch 8/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0265 - accuracy: 0.9930 - val_loss: 0.0760 - val_accuracy: 0.9799
# Epoch 9/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0215 - accuracy: 0.9940 - val_loss: 0.0818 - val_accuracy: 0.9788
# Epoch 10/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0180 - accuracy: 0.9953 - val_loss: 0.0903 - val_accuracy: 0.9758
# Epoch 11/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.0824 - val_accuracy: 0.9793
# Epoch 12/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.0818 - val_accuracy: 0.9790
# Epoch 13/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0873 - val_accuracy: 0.9799
# Epoch 14/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0080 - accuracy: 0.9981 - val_loss: 0.0901 - val_accuracy: 0.9800
# Epoch 15/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.0951 - val_accuracy: 0.9790
# Epoch 16/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.0987 - val_accuracy: 0.9789
# Epoch 17/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0987 - val_accuracy: 0.9803
# Epoch 18/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1058 - val_accuracy: 0.9778
# Epoch 19/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1087 - val_accuracy: 0.9784
# Epoch 20/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1118 - val_accuracy: 0.9804
# Epoch 21/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1114 - val_accuracy: 0.9793
# Epoch 22/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1179 - val_accuracy: 0.9797
# Epoch 23/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1171 - val_accuracy: 0.9804
# Epoch 24/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.1305e-04 - accuracy: 0.9999 - val_loss: 0.1175 - val_accuracy: 0.9803
# Epoch 25/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.5762e-04 - accuracy: 0.9999 - val_loss: 0.1239 - val_accuracy: 0.9793
# Epoch 26/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.1657e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9793
# Epoch 27/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.0416e-04 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9802
# Epoch 28/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.9010e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9797
# Epoch 29/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.5690e-04 - accuracy: 0.9999 - val_loss: 0.1382 - val_accuracy: 0.9782
# Epoch 30/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5813e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9795
# Epoch 31/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4120e-04 - accuracy: 1.0000 - val_loss: 0.1435 - val_accuracy: 0.9798
# Epoch 32/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.8421e-05 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9814
# Epoch 33/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.1632e-04 - accuracy: 0.9999 - val_loss: 0.1489 - val_accuracy: 0.9804
# Epoch 34/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4009e-04 - accuracy: 0.9999 - val_loss: 0.1538 - val_accuracy: 0.9792
# Epoch 35/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.9432e-05 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9802
# Epoch 36/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.7143e-05 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9789
# Epoch 37/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.0420e-05 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.9807
# Epoch 38/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.5732e-05 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9796
# Epoch 39/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.3710e-05 - accuracy: 1.0000 - val_loss: 0.1736 - val_accuracy: 0.9793
# Epoch 40/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.3724e-05 - accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9804
# Epoch 41/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.7327e-06 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9804
# Epoch 42/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.6210e-05 - accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9812
# Epoch 43/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.1696e-06 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9803
# Epoch 44/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.6819e-06 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9803
# Epoch 45/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.3084e-06 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9796
# Epoch 46/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.0611e-06 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9808
# Epoch 47/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0506e-06 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 48/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.2183e-07 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9807
# Epoch 49/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.5129e-06 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9803
# Epoch 50/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.7635e-07 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9810
# Epoch 51/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5256e-07 - accuracy: 1.0000 - val_loss: 0.1921 - val_accuracy: 0.9809
# Epoch 52/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.6256e-08 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9808
# Epoch 53/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.3338e-08 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9807
# Epoch 54/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.2544e-08 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9807
# Epoch 55/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.8522e-08 - accuracy: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9805
# Epoch 56/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.1717e-08 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9805
# Epoch 57/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.0246e-08 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9808
# Epoch 58/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.6819e-08 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9806
# Epoch 59/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.7168e-08 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9808
# Epoch 60/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.3950e-08 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9809
# Epoch 61/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.2252e-08 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9807
# Epoch 62/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.1008e-08 - accuracy: 1.0000 - val_loss: 0.2021 - val_accuracy: 0.9804
# Epoch 63/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.0151e-08 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9807
# Epoch 64/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.8704e-08 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9804
# Epoch 65/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.8382e-08 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9808
# Epoch 66/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7959e-08 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9806
# Epoch 67/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.6141e-08 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9805
# Epoch 68/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5536e-08 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9808
# Epoch 69/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5380e-08 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9807
# Epoch 70/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4981e-08 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9807
# Epoch 71/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4204e-08 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9808
# Epoch 72/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3802e-08 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9808
# Epoch 73/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3481e-08 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9807
# Epoch 74/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2690e-08 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9808
# Epoch 75/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2493e-08 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9807
# Epoch 76/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2322e-08 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9806
# Epoch 77/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2758e-08 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9807
# Epoch 78/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1058e-08 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9808
# Epoch 79/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0973e-08 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9806
# Epoch 80/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0939e-08 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9806
# Epoch 81/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1088e-08 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9807
# Epoch 82/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.8535e-09 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9804
# Epoch 83/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0082e-08 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9807
# Epoch 84/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0001e-08 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9808
# Epoch 85/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.7340e-09 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9807
# Epoch 86/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.3692e-09 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9807
# Epoch 87/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.2605e-09 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9806
# Epoch 88/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.9962e-09 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9806
# Epoch 89/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.9427e-09 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9808
# Epoch 90/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.9428e-09 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9808
# Epoch 91/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.7190e-09 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9808
# Epoch 92/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.1005e-09 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9806
# Epoch 93/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.0601e-09 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9805
# Epoch 94/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.2200e-09 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9809
# Epoch 95/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.0096e-09 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9808
# Epoch 96/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.0341e-09 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9808
# Epoch 97/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.0004e-09 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9808
# Epoch 98/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.5296e-09 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9808
# Epoch 99/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.3587e-09 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9808
# Epoch 100/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.6041e-09 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9808

# %% [markdown]
# > ## 4) 학습 결과 시각화 - Overfitting

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(test_images, test_labels)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1688 - accuracy: 0.9820
# Loss = 0.16882
# Accuracy = 0.98200

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
